# %%
import numpy as np
from scipy.optimize import linprog
from scipy.linalg import eig
from itertools import permutations
import matplotlib.pyplot as plt

def random_doubly_stochastic(n, num_terms=100):
    """Create a random doubly stochastic matrix via convex combinations of permutation matrices."""
    perms = [np.array(p) for p in permutations(range(n))]
    matrices = [np.eye(n)[p] for p in perms]
    weights = np.random.dirichlet(np.ones(len(matrices)), size=1)[0]
    A = sum(w * P for w, P in zip(weights, matrices))
    return A

def kth_roots_of_unity(k):
    """Return the complex k-th roots of unity."""
    return np.array([np.exp(2j * np.pi * i / k) for i in range(k)])

def is_in_convex_hull(z, points):
    """
    Check if complex number z lies in the convex hull of complex points.
    """
    points = np.asarray(points, dtype=np.complex128)
    if len(points.shape) != 1 or len(points) < 2:
        return False  # can't form a convex hull

    num_points = len(points)
    A_eq = np.vstack([
        np.real(points),
        np.imag(points),
        np.ones(num_points)
    ]).T  # shape (num_points, 3) → transpose → (3, num_points)

    b_eq = [np.real(z), np.imag(z), 1.0]
    c = np.zeros(num_points)
    bounds = [(0, 1) for _ in range(num_points)]

    # linprog requires A_eq to be shape (3, num_points) transposed → (num_points, 3)
    if A_eq.shape[1] != len(c):
        return False  # mismatch between vars and equations

    try:
        res = linprog(c, A_eq=A_eq, b_eq=b_eq, bounds=bounds, method='highs')
        return res.success
    except ValueError:
        return False



def check_eigenvalue_in_union(z, n):
    """Check if eigenvalue z lies in ⋃_{k=1}^n Π_k."""
    for k in range(1, n + 1):
        if is_in_convex_hull(z, kth_roots_of_unity(k)):
            return True
    return False

def test_eigenvalues(n, trials=10, verbose=True):
    """Run trials to test if eigenvalues of doubly stochastic matrices lie in the conjectured region."""
    violations = []
    for _ in range(trials):
        A = random_doubly_stochastic(n)
        eigvals = eig(A, left=False, right=False)
        for z in eigvals:
            if not np.isclose(z.imag, 0) or not np.isclose(z.real, 1):  # exclude trivial eigenvalue 1
                if not check_eigenvalue_in_union(z, n):
                    violations.append(z)
                    if verbose:
                        print(f"Violation found: eigenvalue {z}")
    if not violations:
        print(f"No violations found for n={n} in {trials} trials.")
    return violations

# Example usage:
violating_eigs = test_eigenvalues(n=6, trials=50)
# Out:
# Violation found: eigenvalue (-0.05564514893868051+0j)
# Violation found: eigenvalue (0.0442791939156104+0j)
# Violation found: eigenvalue (0.0005403109545555323+0j)
# Violation found: eigenvalue (0.00723910012373181+0j)
# Violation found: eigenvalue (0.015671948942252954+0j)
# Violation found: eigenvalue (0.019385935816385022+0.012414438860818885j)
# Violation found: eigenvalue (0.019385935816385022-0.012414438860818885j)
# Violation found: eigenvalue (-0.005950012836311221+0.022403144979893215j)
# Violation found: eigenvalue (-0.005950012836311221-0.022403144979893215j)
# Violation found: eigenvalue (-0.03181565687277145+0j)
# Violation found: eigenvalue (0.04291459897373297+0j)
# Violation found: eigenvalue (0.023686539345848055+0j)
# Violation found: eigenvalue (-0.04353427148719944+0j)
# Violation found: eigenvalue (-0.02269415194333719+0.018302611132238168j)
# Violation found: eigenvalue (-0.02269415194333719-0.018302611132238168j)
# Violation found: eigenvalue (0.01602279370642337+0.023163478140532115j)
# Violation found: eigenvalue (0.01602279370642337-0.023163478140532115j)
# Violation found: eigenvalue (-0.014620679717321951+0.007496303970812806j)
# Violation found: eigenvalue (-0.014620679717321951-0.007496303970812806j)
# Violation found: eigenvalue (0.011814589966248635+0j)
# Violation found: eigenvalue (0.033253880841194426+0j)
# Violation found: eigenvalue (-0.031963374147518+0j)
# Violation found: eigenvalue (-0.025865089194041027+0.015338833546830554j)
# Violation found: eigenvalue (-0.025865089194041027-0.015338833546830554j)
# Violation found: eigenvalue (-0.00638307796587565+0j)
# Violation found: eigenvalue (0.043242165539540564+0j)
# Violation found: eigenvalue (0.012353478021915821+0.015511434025583517j)
# Violation found: eigenvalue (0.012353478021915821-0.015511434025583517j)
# Violation found: eigenvalue (-0.04256849782113322+0j)
# Violation found: eigenvalue (-0.021112536417006764+0j)
# Violation found: eigenvalue (-0.020805631500800136+0.031071426473122152j)
# Violation found: eigenvalue (-0.020805631500800136-0.031071426473122152j)
# Violation found: eigenvalue (0.025657740518412568+0j)
# Violation found: eigenvalue (0.000352457006966894+0.007231953168124266j)
# Violation found: eigenvalue (0.000352457006966894-0.007231953168124266j)
# Violation found: eigenvalue (0.0011271407933533938+0.03408928749102506j)
# Violation found: eigenvalue (0.0011271407933533938-0.03408928749102506j)
# Violation found: eigenvalue (-0.011304984839931448+0.01316833490504629j)
# Violation found: eigenvalue (-0.011304984839931448-0.01316833490504629j)
# Violation found: eigenvalue (0.0035159795915043115+0j)
# Violation found: eigenvalue (0.025957672238224795+0j)
# Violation found: eigenvalue (0.004818831187435656+0j)
# Violation found: eigenvalue (-0.009809078676093728+0.024342706480561218j)
# Violation found: eigenvalue (-0.009809078676093728-0.024342706480561218j)
# Violation found: eigenvalue (-0.02486740746352064+0j)
# Violation found: eigenvalue (-0.02283603877646119+0.02452539785974162j)
# Violation found: eigenvalue (-0.02283603877646119-0.02452539785974162j)
# Violation found: eigenvalue (0.031157620217107995+0j)
# Violation found: eigenvalue (0.01886513509767987+0j)
# Violation found: eigenvalue (-0.003910211272343718+0j)
# Violation found: eigenvalue (-0.03853631064994521+0j)
# Violation found: eigenvalue (-0.0028129359098395526+0.039713326756268805j)
# Violation found: eigenvalue (-0.0028129359098395526-0.039713326756268805j)
# Violation found: eigenvalue (0.011491732458831241+0.021165848674218j)
# Violation found: eigenvalue (0.011491732458831241-0.021165848674218j)
# Violation found: eigenvalue (0.025408107407037653+0j)
# Violation found: eigenvalue (0.014227586331712866+0j)
# Violation found: eigenvalue (-0.02536842752903819+0j)
# Violation found: eigenvalue (-0.01683703571468105+0.0020051111756596365j)
# Violation found: eigenvalue (-0.01683703571468105-0.0020051111756596365j)
# Violation found: eigenvalue (0.04736282416654403+0j)
# Violation found: eigenvalue (-0.0430529467123209+0j)
# Violation found: eigenvalue (0.018464227541278435+0j)
# Violation found: eigenvalue (-0.010987085696231202+0j)
# Violation found: eigenvalue (-0.012618850795408617+0j)
# Violation found: eigenvalue (-0.040773125402624164+0j)
# Violation found: eigenvalue (-0.028660599197948965+0j)
# Violation found: eigenvalue (0.022476044889479817+0.015551186038654j)
# Violation found: eigenvalue (0.022476044889479817-0.015551186038654j)
# Violation found: eigenvalue (0.011399296565865032+0j)
# Violation found: eigenvalue (0.035819638010643286+0.011792728006235601j)
# Violation found: eigenvalue (0.035819638010643286-0.011792728006235601j)
# Violation found: eigenvalue (-0.04962431946265537+0j)
# Violation found: eigenvalue (-0.03212272209630821+0j)
# Violation found: eigenvalue (-0.0028469294753568223+0j)
# Violation found: eigenvalue (-0.018172981947870783+0.014499498871129352j)
# Violation found: eigenvalue (-0.018172981947870783-0.014499498871129352j)
# Violation found: eigenvalue (0.038005125148440747+0j)
# Violation found: eigenvalue (0.015681640375364514+0.019055893468138938j)
# Violation found: eigenvalue (0.015681640375364514-0.019055893468138938j)
# Violation found: eigenvalue (0.019890634036688795+0.007478411325480747j)
# Violation found: eigenvalue (0.019890634036688795-0.007478411325480747j)
# Violation found: eigenvalue (0.005920346559500416+0.019546064575045367j)
# Violation found: eigenvalue (0.005920346559500416-0.019546064575045367j)
# Violation found: eigenvalue (-0.019227776906596692+0j)
# Violation found: eigenvalue (-0.02593678037470139+0j)
# Violation found: eigenvalue (0.03256723684026601+0.02737430331823993j)
# Violation found: eigenvalue (0.03256723684026601-0.02737430331823993j)
# Violation found: eigenvalue (0.01465148964982357+0.006658998909981174j)
# Violation found: eigenvalue (0.01465148964982357-0.006658998909981174j)
# Violation found: eigenvalue (-0.04551732460112383+0.00687733349827043j)
# Violation found: eigenvalue (-0.04551732460112383-0.00687733349827043j)
# Violation found: eigenvalue (0.04417957712451469+0j)
# Violation found: eigenvalue (0.020935178148047236+0j)
# Violation found: eigenvalue (-0.002196087621881977+0j)
# Violation found: eigenvalue (0.03437355009219449+0j)
# Violation found: eigenvalue (-0.04288500125917478+0j)
# Violation found: eigenvalue (0.007888737912723863+0j)
# Violation found: eigenvalue (-0.012769664804794486+0j)
# Violation found: eigenvalue (-0.020562920196470644+0j)
# Violation found: eigenvalue (-0.034255210671671546+0j)
# Violation found: eigenvalue (0.025399465919799812+0.016450858148386j)
# Violation found: eigenvalue (0.025399465919799812-0.016450858148386j)
# Violation found: eigenvalue (0.015000425939993052+0j)
# Violation found: eigenvalue (-0.012396446372111342+0j)
# Violation found: eigenvalue (0.04799630327216793+0j)
# Violation found: eigenvalue (-0.037660602901828454+0j)
# Violation found: eigenvalue (-0.013298198169361768+0.012915311253086557j)
# Violation found: eigenvalue (-0.013298198169361768-0.012915311253086557j)
# Violation found: eigenvalue (0.007382678261409268+0j)
# Violation found: eigenvalue (-0.026516802802995874+0j)
# Violation found: eigenvalue (-0.01257767232964037+0j)
# Violation found: eigenvalue (0.023801037700899176+0.015033650996671609j)
# Violation found: eigenvalue (0.023801037700899176-0.015033650996671609j)
# Violation found: eigenvalue (0.01855438302315177+0j)
# Violation found: eigenvalue (0.042033491623989755+0j)
# Violation found: eigenvalue (0.007427149640975437+0.0046057217941368415j)
# Violation found: eigenvalue (0.007427149640975437-0.0046057217941368415j)
# Violation found: eigenvalue (-0.02348427869090994+0j)
# Violation found: eigenvalue (-0.012140373372037608+0j)
# Violation found: eigenvalue (0.03345630613929795+0j)
# Violation found: eigenvalue (0.010337657183069391+0.025771867527212895j)
# Violation found: eigenvalue (0.010337657183069391-0.025771867527212895j)
# Violation found: eigenvalue (-0.015392183838380353+0j)
# Violation found: eigenvalue (0.007619639949881173+0j)
# Violation found: eigenvalue (-0.007626647043467284+0.028521053933059974j)
# Violation found: eigenvalue (-0.007626647043467284-0.028521053933059974j)
# Violation found: eigenvalue (0.01377043813634931+0j)
# Violation found: eigenvalue (-0.0010581370213565634+0j)
# Violation found: eigenvalue (-0.014132440405274971+0j)
# Violation found: eigenvalue (-0.0212047996425758+0j)
# Violation found: eigenvalue (-0.007052481727129014+0j)
# Violation found: eigenvalue (0.013719227590949951+0.01891987367814317j)
# Violation found: eigenvalue (0.013719227590949951-0.01891987367814317j)
# Violation found: eigenvalue (0.018873891129557802+0j)
# Violation found: eigenvalue (0.011660609437154183+0j)
# Violation found: eigenvalue (-0.03649295090551079+0.01391955480066232j)
# Violation found: eigenvalue (-0.03649295090551079-0.01391955480066232j)
# Violation found: eigenvalue (-0.0120807293311223+0.008194388853128265j)
# Violation found: eigenvalue (-0.0120807293311223-0.008194388853128265j)
# Violation found: eigenvalue (-0.012346393302313446+0j)
# Violation found: eigenvalue (0.02326027322532431+0.017522795407366207j)
# Violation found: eigenvalue (0.02326027322532431-0.017522795407366207j)
# Violation found: eigenvalue (0.03767954044045498+0j)
# Violation found: eigenvalue (0.022087962680637663+0j)
# Violation found: eigenvalue (-0.05105887903229642+0j)
# Violation found: eigenvalue (-0.02203950592683285+0j)
# Violation found: eigenvalue (0.027133171648489485+0j)
# Violation found: eigenvalue (0.01612615168488965+0.009857702869617046j)
# Violation found: eigenvalue (0.01612615168488965-0.009857702869617046j)
# Violation found: eigenvalue (-0.011177481996626578+0.017652463591162647j)
# Violation found: eigenvalue (-0.011177481996626578-0.017652463591162647j)
# Violation found: eigenvalue (0.015206751204765154+0j)
# Violation found: eigenvalue (0.004415677707465458+0.012421812785064648j)
# Violation found: eigenvalue (0.004415677707465458-0.012421812785064648j)
# Violation found: eigenvalue (0.03558549966036986+0j)
# Violation found: eigenvalue (-0.020395862012581423+0.018010794444364774j)
# Violation found: eigenvalue (-0.020395862012581423-0.018010794444364774j)
# Violation found: eigenvalue (0.009275912182444739+0j)
# Violation found: eigenvalue (-0.020297742482022825+0j)
# Violation found: eigenvalue (-0.0404381645335854+0j)
# Violation found: eigenvalue (-0.0017102335761441487+0j)
# Violation found: eigenvalue (0.053724417234269066+0j)
# Violation found: eigenvalue (0.025912629425198206+0.005157399671507569j)
# Violation found: eigenvalue (0.025912629425198206-0.005157399671507569j)
# Violation found: eigenvalue (0.04158287603659606+0j)
# Violation found: eigenvalue (-0.016516311512119918+0.017355006653095893j)
# Violation found: eigenvalue (-0.016516311512119918-0.017355006653095893j)
# Violation found: eigenvalue (-0.00951291217079549+0j)
# Violation found: eigenvalue (0.010793233130873426+0j)
# Violation found: eigenvalue (0.029811089233084682+0j)
# Violation found: eigenvalue (-0.023219099086189528+0.016099001285895594j)
# Violation found: eigenvalue (-0.023219099086189528-0.016099001285895594j)
# Violation found: eigenvalue (0.0073554058938638915+0.009791809018458707j)
# Violation found: eigenvalue (0.0073554058938638915-0.009791809018458707j)
# Violation found: eigenvalue (-0.04449888802847604+0j)
# Violation found: eigenvalue (-0.0097139308210329+0.017279647912023657j)
# Violation found: eigenvalue (-0.0097139308210329-0.017279647912023657j)
# Violation found: eigenvalue (0.04086962525068372+0j)
# Violation found: eigenvalue (0.01578519407209583+0j)
# Violation found: eigenvalue (-0.03047014622075695+0j)
# Violation found: eigenvalue (0.004511792764013661+0.0266086886245327j)
# Violation found: eigenvalue (0.004511792764013661-0.0266086886245327j)
# Violation found: eigenvalue (0.008585084766413013+0.004509842351674799j)
# Violation found: eigenvalue (0.008585084766413013-0.004509842351674799j)
# Violation found: eigenvalue (-0.02065441037176862+0.004765167228262862j)
# Violation found: eigenvalue (-0.02065441037176862-0.004765167228262862j)
# Violation found: eigenvalue (0.03231844019223533+0.014156354869361903j)
# Violation found: eigenvalue (0.03231844019223533-0.014156354869361903j)
# Violation found: eigenvalue (0.03371347450539096+0j)
# Violation found: eigenvalue (-0.034558024035898395+0j)
# Violation found: eigenvalue (0.01829107895023734+0j)
# Violation found: eigenvalue (-0.012876927329557811+0j)
# Violation found: eigenvalue (0.0004409683939750604+0.03076565660943593j)
# Violation found: eigenvalue (0.0004409683939750604-0.03076565660943593j)
# Violation found: eigenvalue (0.02660963726015756+0.009785071355054395j)
# Violation found: eigenvalue (0.02660963726015756-0.009785071355054395j)
# Violation found: eigenvalue (-0.00630720133499378+0.013122308154645709j)
# Violation found: eigenvalue (-0.00630720133499378-0.013122308154645709j)
# Violation found: eigenvalue (-0.009788702753441797+0j)
# Violation found: eigenvalue (0.046901155125335006+0j)
# Violation found: eigenvalue (-0.007302977521487229+0.030143272663467755j)
# Violation found: eigenvalue (-0.007302977521487229-0.030143272663467755j)
# Violation found: eigenvalue (0.016916182343543168+0j)
# Violation found: eigenvalue (-0.008121245298947397+0j)
# Violation found: eigenvalue (-0.03390618393342515+0.04123313394238772j)
# Violation found: eigenvalue (-0.03390618393342515-0.04123313394238772j)
# Violation found: eigenvalue (0.001948564121863701+0.010705569759528232j)
# Violation found: eigenvalue (0.001948564121863701-0.010705569759528232j)
# Violation found: eigenvalue (0.010957069116709852+0j)
# Violation found: eigenvalue (-0.04886799280416794+0j)
# Violation found: eigenvalue (0.03601814009754141+0j)
# Violation found: eigenvalue (0.012826042730615857+0j)
# Violation found: eigenvalue (-0.009226836609410807+0.013264994256250053j)
# Violation found: eigenvalue (-0.009226836609410807-0.013264994256250053j)
# Violation found: eigenvalue (0.04813919552733655+0j)
# Violation found: eigenvalue (-0.01514278992616025+0.013697087469190187j)
# Violation found: eigenvalue (-0.01514278992616025-0.013697087469190187j)
# Violation found: eigenvalue (0.015913628987008193+0.0053354855560485154j)
# Violation found: eigenvalue (0.015913628987008193-0.0053354855560485154j)
# Violation found: eigenvalue (-0.03865516589901339+0j)
# Violation found: eigenvalue (0.009635210640483732+0.020282345164387455j)
# Violation found: eigenvalue (0.009635210640483732-0.020282345164387455j)
# Violation found: eigenvalue (0.012709884650001658+0.021923599212588466j)
# Violation found: eigenvalue (0.012709884650001658-0.021923599212588466j)
# Violation found: eigenvalue (0.007774509537374727+0.03919665327003639j)
# Violation found: eigenvalue (0.007774509537374727-0.03919665327003639j)
# Violation found: eigenvalue (0.04771196261659256+0j)
# Violation found: eigenvalue (0.029123974161102517+0j)
# Violation found: eigenvalue (0.0003732214452062286+0j)
# Violation found: eigenvalue (-0.03395931491674534+0j)
# Violation found: eigenvalue (0.027433414562699623+0.01667647845929778j)
# Violation found: eigenvalue (0.027433414562699623-0.01667647845929778j)
# Violation found: eigenvalue (0.013702054772125594+0j)
# Violation found: eigenvalue (0.007294735248147582+0j)
# Violation found: eigenvalue (-0.026905978390599664+0j)
# Violation found: eigenvalue (0.014686225476417718+0.007388800164213863j)
# Violation found: eigenvalue (0.014686225476417718-0.007388800164213863j)
# Violation found: eigenvalue (-0.006234592147722563+0.012299472791192955j)
# Violation found: eigenvalue (-0.006234592147722563-0.012299472791192955j)
# Violation found: eigenvalue (0.02354893503763518+0j)
# Violation found: eigenvalue (0.0012118814613050878+0.024867887949231095j)
# Violation found: eigenvalue (0.0012118814613050878-0.024867887949231095j)
# Violation found: eigenvalue (-0.008621272982748597+0.006321743783709504j)
# Violation found: eigenvalue (-0.008621272982748597-0.006321743783709504j)
# Violation found: eigenvalue (0.01842751107142801+0.012609705725259166j)
# Violation found: eigenvalue (0.01842751107142801-0.012609705725259166j)
# Violation found: eigenvalue (-0.02484640200248179+0.02237123980151582j)
# Violation found: eigenvalue (-0.02484640200248179-0.02237123980151582j)
# Violation found: eigenvalue (-0.007985678185280475+0j)
